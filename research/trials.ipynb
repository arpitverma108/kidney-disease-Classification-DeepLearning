# %%
from box import ConfigBox
from ensure import ensure_annotations

# %% [markdown]
# ## Downlaod data from google drive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1Lr9Il89ktp1vVHHw9Ejg57l7bXVmgzPi/view?usp=sharing"

# %%
file_id=url.split('/')[-2]
file_id
# Out:
# '1Lr9Il89ktp1vVHHw9Ejg57l7bXVmgzPi'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1Lr9Il89ktp1vVHHw9Ejg57l7bXVmgzPi
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1Lr9Il89ktp1vVHHw9Ejg57l7bXVmgzPi&confirm=t&uuid=94aef20e-0893-4bb5-91e1-1ca742218706
# To: /Users/arpitverma/kidney-disease-Classification-DeepLearning/research/kidney-CT-Scan-data.zip
# 100%|██████████| 1.63G/1.63G [01:03<00:00, 25.5MB/s]
# 'kidney-CT-Scan-data.zip'
